# %% [markdown]
# # Merge and Clean Datasets

# %%
import pandas as pd
from fuzzywuzzy import process
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Load Data

# %%
# Load datasets
qs_data = pd.read_csv('qs_data.csv')
scorecard_data = pd.read_csv('scorecard_data.csv')
ntu_data = pd.read_csv('ntu_research_ranking.csv')
size_data = pd.read_csv('campus_data.csv')
sentiment_data = pd.read_csv('RMP_Data_Clean_Organized.csv')

# %% [markdown]
# # Clean Data

# %%
# Filter QS data for useful metrics only
qs_data = qs_data[['institution',
                   'ar score',
                   'er score',
                   'isr score',
                   'fsr score',
                   'ifr score']]

# %%
# Set standard university names
standard_names = ['Princeton University',
 'Massachusetts Institute of Technology',
 'Harvard University',
 'Stanford University',
 'Yale University',
 'California Institute of Technology',
 'Duke University',
 'Johns Hopkins University',
 'Northwestern University',
 'University of Pennsylvania',
 'Cornell University',
 'University of Chicago',
 'Brown University',
 'Columbia University',
 'Dartmouth College',
 'University of California, Los Angeles',
 'University of California, Berkeley',
 'Rice University',
 'University of Notre Dame',
 'Vanderbilt University',
 'Carnegie Mellon University',
 'University of Michigan, Ann Arbor',
 'Washington University',
 'Emory University',
 'Georgetown University',
 'University of Virginia',
 'University of North Carolina, Chapel Hill',
 'University of Southern California',
 'University of California, San Diego',
 'New York University',
 'University of Florida',
 'University of Texas, Austin',
 'Georgia Institute of Technology',
 'University of California, Davis',
 'University of California, Irvine',
 'University of Illinois, Urbana-Champaign',
 'Boston College',
 'Tufts University',
 'University of California, Santa Barbara',
 'University of Wisconsin, Madison',
 'Boston University',
 'Ohio State University, Columbus',
 'Rutgers University, New Brunswick',
 'University of Maryland, College Park',
 'University of Rochester',
 'Lehigh University',
 'Purdue University',
 'University of Georgia',
 'University of Washington',
 'Wake Forest University']

# %%
def standardize_column_values(df, column, standard_names, threshold=80):

    updated_values = []
    
    for value in df[column]:
        match, score = process.extractOne(value, standard_names)
        if score >= threshold:
            updated_values.append(match)  # Use the matched standard name
        else:
            updated_values.append(value)  # Keep the original name if no good match
    
    df[column] = updated_values
    return df

# %%
# Standardize university names across datasets
ntu_data = standardize_column_values(ntu_data, 'University Name', standard_names, threshold=80)
qs_data = standardize_column_values(qs_data, 'institution', standard_names, threshold=80)
size_data = standardize_column_values(size_data, 'College or University', standard_names, threshold=80)
scorecard_data = standardize_column_values(scorecard_data, 'University Name', standard_names, threshold=80)
sentiment_data = standardize_column_values(sentiment_data, 'University', standard_names, threshold=80)

# Rename university columns for easier merging
size_data.rename(columns={'College or University': 'University Name'}, inplace=True)
qs_data.rename(columns={'institution': 'University Name'}, inplace=True)
sentiment_data.rename(columns={'University': 'University Name'}, inplace=True)

# Rename OSU, Columbus to OSU
size_data.loc[11, 'University Name'] = 'Ohio State University, Columbus'
qs_data.loc[31, 'University Name'] = 'Ohio State University, Columbus'

# %%
# Merge DataFrames (outer merge for easier detection of problems)
merged_df = scorecard_data.merge(ntu_data, on='University Name', how='outer') \
                          .merge(qs_data, on='University Name', how='outer') \
                          .merge(size_data, on='University Name', how='outer') \
                          .merge(sentiment_data, on='University Name', how='outer')

# Drop duplicate universities
merged_df = merged_df.drop_duplicates(subset=['University Name']).reset_index(drop=True)

# Show DataFrame
merged_df
# Out:
#                               University Name  In State Tuition  \
# 0                              Boston College             22144
# 1                           Boston University             62360
# 2                            Brown University             29720
# 3          California Institute of Technology             19190
# 4                  Carnegie Mellon University             61344
# 5                         Columbia University             66139
# 6                          Cornell University             63200
# 7                           Dartmouth College             62658
# 8                             Duke University             62688
# 9                            Emory University             57948
# 10                      Georgetown University             62052
# 11            Georgia Institute of Technology             11764
# 12                         Harvard University             57261
# 13                   Johns Hopkins University             60480
# 14                          Lehigh University             59930
# 15      Massachusetts Institute of Technology             57986
# 16                        New York University              8524
# 17                    Northwestern University              8672
# 18            Ohio State University, Columbus              8998
# 19                       Princeton University             57410
# 20                          Purdue University              8985
# 21                            Rice University             54960
# 22          Rutgers University, New Brunswick             16112
# 23                        Stanford University             58416
# 24                           Tufts University             65222
# 25         University of California, Berkeley             14395
# 26            University of California, Davis             14858
# 27           University of California, Irvine             13939
# 28      University of California, Los Angeles              6805
# 29        University of California, San Diego             14906
# 30    University of California, Santa Barbara             14617
# 31                      University of Chicago             14046
# 32                      University of Florida              5656
# 33                      University of Georgia              4980
# 34   University of Illinois, Urbana-Champaign             15714
# 35       University of Maryland, College Park             53430
# 36          University of Michigan, Ann Arbor             16736
# 37  University of North Carolina, Chapel Hill              8989
# 38                   University of Notre Dame             60301
# 39                 University of Pennsylvania             63452
# 40                    University of Rochester             26736
# 41          University of Southern California             38700
# 42                University of Texas, Austin             11698
# 43                     University of Virginia             20342
# 44                   University of Washington              8967
# 45           University of Wisconsin, Madison             10796
# 46                      Vanderbilt University             60348
# 47                     Wake Forest University             62128
# 48                      Washington University              8967
# 49                            Yale University             62250
#
#     Out of State Tuition  Admission Rate  Number of Students  \
# 0                  22144          0.1670                 259
# 1                  62360          0.1437               17668
# 2                  29720          0.5664                1354
# 3                  19190          0.0270                 540
# 4                  61344          0.1130                7005
# 5                  66139          0.0395                8902
# 6                  63200          0.0790               16071
# 7                  62658          0.0638                4412
# 8                  62688          0.0635                6570
# 9                  57948          0.1135                7017
# 10                 62052          0.1223                7343
# 11                 32876          0.1713               17379
# 12                 57261          0.0324                7973
# 13                 60480          0.0725                5643
# 14                 59930          0.3698                5612
# 15                 57986          0.0396                4638
# 16                 18434          0.5827                5990
# 17                 19460          0.9793                6243
# 18                 33235          0.0270                 421
# 19                 57410          0.0570                5527
# 20                 21573          0.8066                5482
# 21                 54960          0.0868                4480
# 22                 33812          0.7652                4077
# 23                 58416          0.0368                7761
# 24                 65222          0.0969                6747
# 25                 44467          0.1133               32475
# 26                 44930          0.3734               31512
# 27                 44011          0.2115               28651
# 28                 18685          0.8694               22690
# 29                 44978          0.2371               33092
# 30                 44689          0.2585               23419
# 31                 28654          0.7869               21567
# 32                 18786          0.2504               32691
# 33                 15702          0.7318                2092
# 34                 33686          0.4482               34031
# 35                 53430          0.8348                3968
# 36                 55334          0.1769               32448
# 37                 37550          0.1711               19921
# 38                 60301          0.1291                8917
# 39                 63452          0.0650               10572
# 40                 26736          0.7137                 848
# 41                 38700          0.7484                2001
# 42                 41070          0.3135               40980
# 43                 55914          0.1866               17103
# 44                 26873          0.9269               13686
# 45                 39427          0.4906               35184
# 46                 60348          0.0667                7144
# 47                 62128          0.2137                5446
# 48                 26873          0.9269               13686
# 49                 62250          0.0457                6639
#
#     Graduation Rate 4-years  Earnings After 10 Years  Retention Rate  \
# 0                    0.4545                    62123          0.8235
# 1                    0.8916                    83238          0.9397
# 2                    0.7078                    53907          0.8445
# 3                    0.7828                    53598          0.9474
# 4                    0.9214                   114862          0.9730
# 5                    0.9528                   102491          0.9792
# 6                    0.8800                   104043          0.9600
# 7                    0.9448                    97434          0.9803
# 8                    0.9625                    97800          0.9685
# 9                    0.9002                    80137          0.9521
# 10                   0.9541                   103494          0.9658
# 11                   0.9225                   102772          0.9786
# 12                   0.9726                   101817          0.9769
# 13                   0.9433                    87555          0.9695
# 14                   0.8926                   105584          0.9085
# 15                   0.9557                   143372          0.9898
# 16                   0.7327                    58073          0.8416
# 17                   0.4528                    47021          0.6115
# 18                   0.6700                    60409          0.5149
# 19                   0.9744                   110066          0.9705
# 20                   0.3701                    45872          0.6272
# 21                   0.9299                    89718          0.9810
# 22                   0.6716                    74479          0.7856
# 23                   0.9534                   124080          0.9831
# 24                   0.9376                    83214          0.9605
# 25                   0.9346                    92446          0.9588
# 26                   0.8663                    80838          0.9190
# 27                   0.8523                    80735          0.9127
# 28                   0.5166                    59211          0.7348
# 29                   0.8851                    84943          0.9339
# 30                   0.8553                    74915          0.9236
# 31                   0.6195                    68740          0.7832
# 32                   0.8402                    61675          0.9393
# 33                   0.3522                    48757          0.5973
# 34                   0.8479                    81054          0.9332
# 35                   0.7956                    82652          0.8458
# 36                   0.9340                    83648          0.9721
# 37                   0.9161                    72200          0.9598
# 38                   0.9612                    99980          0.9738
# 39                   0.9615                   111371          0.9837
# 40                   0.4016                    48707          0.6090
# 41                   0.6044                    59541          0.7227
# 42                   0.8777                    75121          0.9530
# 43                   0.9446                    86863          0.9694
# 44                   0.6650                    62569          0.7736
# 45                   0.8921                    73792          0.9433
# 46                   0.9308                    91565          0.9643
# 47                   0.8994                    78158          0.9376
# 48                   0.6650                    62569          0.7736
# 49                   0.9736                   100533          0.9810
#
#     Diversity Score  Public or Private  ...  ar score  er score  isr score  \
# 0          0.597781  Private Nonprofit  ...      20.5      12.9       18.3
# 1          0.671706  Private Nonprofit  ...      61.7      68.3       87.5
# 2          0.431634  Private Nonprofit  ...      58.3      42.4       52.0
# 3          0.483280        Proprietary  ...      96.1      93.7       81.0
# 4          0.673670  Private Nonprofit  ...      71.2      75.3       98.2
# 5          0.679876  Private Nonprofit  ...      99.6      98.3       96.8
# 6          0.661828  Private Nonprofit  ...      98.1      90.5       64.0
# 7          0.644170  Private Nonprofit  ...      21.1      24.2       33.9
# 8          0.700444  Private Nonprofit  ...      85.7      69.3       52.2
# 9          0.706744  Private Nonprofit  ...      25.6      16.4       31.1
# 10         0.632342  Private Nonprofit  ...      30.3      34.4       39.8
# 11         0.700213             Public  ...      67.4      85.1       65.4
# 12         0.703174  Private Nonprofit  ...     100.0     100.0       66.8
# 13         0.688898  Private Nonprofit  ...      87.3      59.7       91.4
# 14         0.567735  Private Nonprofit  ...       5.8       4.2       29.6
# 15         0.699191  Private Nonprofit  ...     100.0     100.0       88.2
# 16         0.557727             Public  ...      95.9      98.5       95.0
# 17         0.600800             Public  ...      83.8      60.2       44.2
# 18         0.129708             Public  ...      59.4      55.8       16.5
# 19         0.701479  Private Nonprofit  ...      99.8      97.5       57.5
# 20         0.455198             Public  ...      63.9      81.2       45.8
# 21         0.708928  Private Nonprofit  ...      38.7      22.9       94.8
# 22         0.710127             Public  ...      36.9      24.7       32.8
# 23         0.694972  Private Nonprofit  ...     100.0     100.0       51.2
# 24         0.659435  Private Nonprofit  ...      18.1       5.3       36.2
# 25         0.654043             Public  ...     100.0     100.0       63.9
# 26         0.646977             Public  ...      63.9      44.7       49.3
# 27         0.618169             Public  ...      37.6      16.6       49.6
# 28         0.335057             Public  ...     100.0      99.8       24.8
# 29         0.639903             Public  ...      89.1      50.4       51.3
# 30         0.634496             Public  ...      54.8      19.0       21.6
# 31         0.665014             Public  ...      99.1      95.4       84.4
# 32         0.559907             Public  ...      48.0      58.7       10.8
# 33         0.585268             Public  ...      20.9      18.2        4.5
# 34         0.686578             Public  ...      85.0      70.8       49.2
# 35         0.516167  Private Nonprofit  ...      49.2      26.1       14.0
# 36         0.632797             Public  ...      98.3      89.9       27.6
# 37         0.620395             Public  ...      63.0      33.9       10.1
# 38         0.518160  Private Nonprofit  ...      26.5      32.2       17.7
# 39         0.709739  Private Nonprofit  ...      96.4      89.1       70.3
# 40         0.558933  Private Nonprofit  ...      22.1      18.4       91.7
# 41         0.548857  Private Nonprofit  ...      52.5      47.6       73.5
# 42         0.684622             Public  ...      93.5      83.2       11.0
# 43         0.637681             Public  ...      35.6      32.0       10.8
# 44         0.468993             Public  ...      84.0      50.4       33.2
# 45         0.534317             Public  ...      80.2      47.8       22.8
# 46         0.694480  Private Nonprofit  ...      25.2      19.8       34.6
# 47         0.503522  Private Nonprofit  ...       5.4       6.1       13.5
# 48         0.468993             Public  ...      38.6      10.4       68.0
# 49         0.702715  Private Nonprofit  ...      99.9      99.9       78.8
#
#     fsr score  ifr score   Acres  Safety  Facilities  Social  \
# 0        19.3       12.0   240.0     4.7         4.3     3.8
# 1        32.7       21.6   140.0     4.2         3.7     3.7
# 2        77.8       84.5   146.0     4.5         4.4     4.5
# 3       100.0      100.0   124.0     4.2         4.3     3.6
# 4        49.1       46.6   150.0     4.3         4.0     3.2
# 5       100.0       56.1    36.0     3.5         3.9     3.3
# 6        52.9       68.7  2300.0     4.4         4.6     4.0
# 7        57.9        5.3   269.0     4.2         4.5     4.1
# 8       100.0       16.8  8693.0     4.4         4.8     4.4
# 9        97.7       37.3   600.0     4.7         4.6     3.7
# 10       59.0       17.0   104.0     4.2         3.9     4.1
# 11       15.3       38.8   400.0     3.9         4.2     3.6
# 12       98.3       84.6   209.0     3.2         3.2     2.9
# 13      100.0       64.4   140.0     3.2         4.3     3.3
# 14       26.2       62.4  2355.0     3.6         4.3     4.2
# 15      100.0      100.0   168.0     4.5         3.7     3.7
# 16       95.5       26.4   230.0     3.5         3.9     3.7
# 17       98.9       48.2   242.8     4.3         4.3     3.7
# 18       53.8       49.7  1700.0     3.4         4.3     4.3
# 19       64.5       16.7   600.0     4.5         4.4     4.1
# 20       10.3       41.5  2500.0     4.5         4.2     3.9
# 21       65.9       91.0   300.0     4.3         4.5     3.9
# 22       48.7       18.9  2600.0     3.2         3.8     4.1
# 23      100.0       99.9  8180.0     4.5         4.5     4.0
# 24       56.2       25.2   750.0     4.3         4.2     3.9
# 25       20.5       92.2  1232.0     2.7         4.1     4.0
# 26       30.4       70.3  5300.0     4.3         4.3     3.8
# 27       14.6       56.9  1475.0     4.7         4.4     3.6
# 28       36.6       43.4   419.0     4.0         4.4     4.1
# 29       49.6       68.1  1200.0     4.2         3.8     3.0
# 30        9.5       70.4   989.0     3.7         4.4     4.5
# 31       92.5       81.2   217.0     2.9         4.1     3.0
# 32       71.3       18.8  2000.0     4.2         4.4     4.4
# 33        9.7        9.7   760.0     4.0         4.6     4.5
# 34        7.5       11.1  6370.0     3.7         4.4     4.3
# 35       35.1       31.6  1347.0     3.1         3.9     3.9
# 36       82.2       67.0  3070.0     4.4         4.5     4.4
# 37       72.9       24.7   250.0     4.0         4.3     4.4
# 38       59.7       23.3  1250.0     4.4         4.6     4.1
# 39       99.9       96.0   299.0     3.5         4.2     4.2
# 40       97.9       71.4   707.0     3.5         4.0     3.3
# 41       21.7       31.8   226.0     3.5         4.6     4.6
# 42        8.9        9.3   431.0     3.4         4.3     4.4
# 43       56.9        7.9  2000.0     4.0         4.5     4.4
# 44       19.1       19.0   700.0     3.0         4.3     3.5
# 45       61.3       30.9   939.0     4.3         4.6     4.8
# 46      100.0       36.4   340.0     4.5         4.6     4.5
# 47      100.0        5.4   340.0     4.5         4.6     3.9
# 48       99.8       84.3   169.0     3.9         4.8     4.1
# 49      100.0       89.8  1108.0     3.6         4.1     4.0
#
#     Average Sentiment
# 0            0.596994
# 1            0.376901
# 2            0.694265
# 3            0.458000
# 4            0.324381
# 5            0.356867
# 6            0.553095
# 7            0.651600
# 8            0.729300
# 9            0.565966
# 10           0.592403
# 11           0.608664
# 12           0.249510
# 13           0.492445
# 14           0.439636
# 15           0.585213
# 16           0.522103
# 17           0.699360
# 18           0.601412
# 19           0.534225
# 20           0.453190
# 21           0.510343
# 22           0.459006
# 23           0.581759
# 24           0.657181
# 25           0.639878
# 26           0.485957
# 27           0.596998
# 28           0.442562
# 29           0.540381
# 30           0.540311
# 31           0.382426
# 32           0.544867
# 33           0.664612
# 34           0.674779
# 35           0.506150
# 36           0.628548
# 37           0.545125
# 38           0.645090
# 39           0.521849
# 40           0.408761
# 41           0.634236
# 42           0.628562
# 43           0.610032
# 44           0.545101
# 45           0.650446
# 46           0.647536
# 47           0.647837
# 48           0.530060
# 49           0.597000
#
# [50 rows x 21 columns]

# %%
# Save to file
merged_df.to_csv('merged_datasets.csv',index=False)
