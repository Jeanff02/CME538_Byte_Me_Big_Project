# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import matplotlib.pylab as plt
import seaborn as sns
import plotly.express as px
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import AgglomerativeClustering
import tkinter as tk
from tkinter import messagebox

# %%
uni_data = pd.read_csv('merged_datasets.csv')
uni_data.drop(columns = ['University ID'], inplace=True)
uni_data.head()
# Out:
#                       University Name  In State Tuition  Out of State Tuition  \
# 0                      Boston College             22144                 22144
# 1                   Boston University             62360                 62360
# 2                    Brown University             29720                 29720
# 3  California Institute of Technology             19190                 19190
# 4          Carnegie Mellon University             61344                 61344
#
#    Admission Rate  Number of Students  Graduation Rate 4-years  \
# 0          0.1670                 259                   0.4545
# 1          0.1437               17668                   0.8916
# 2          0.5664                1354                   0.7078
# 3          0.0270                 540                   0.7828
# 4          0.1130                7005                   0.9214
#
#    Earnings After 10 Years  Retention Rate  Diversity Score  \
# ...

# %%
# Creates a heatmap to show correlation
fig, axs = plt.subplots(figsize=(8, 8))  
uni_data_corr = uni_data.select_dtypes(include='number')
sns.heatmap(uni_data_corr.corr().abs(), annot=True, square=True, annot_kws={'size': 7}, fmt='.2f',cbar_kws={"shrink": 0.73}) 
axs.tick_params(axis='x', labelsize=8)  
axs.tick_params(axis='y', labelsize=8)  
axs.set_title('Correlation Chart', size=10)
plt.tight_layout()  
plt.show()
