# %%
pip install meteostat
# Out:
# Requirement already satisfied: meteostat in /opt/conda/lib/python3.11/site-packages (1.6.8)
# Requirement already satisfied: pandas>=1.1 in /opt/conda/lib/python3.11/site-packages (from meteostat) (2.1.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from meteostat) (2023.3.post1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from meteostat) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1->meteostat) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import time
import folium
from folium import Marker
from folium.plugins import HeatMap

# %%
# Top 50 Schools

# %%
# List of universities

universities = ["Princeton University", "Massachusetts Institute of Technology", "Harvard University",
    "Stanford University", "Yale University", "California Institute of Technology",
    "Duke University", "Johns Hopkins University", "Northwestern University",
    "University of Pennsylvania", "Cornell University", "University of Chicago",
    "Brown University", "Columbia University", "Dartmouth College",
    "University of California-Los Angeles", "University of California-Berkeley", "Rice University",
    "University of Notre Dame", "Vanderbilt University", "Carnegie Mellon University",
    "University of Michigan-Ann Arbor", "Washington University in St. Louis", "Emory University",
    "Georgetown University", "University of Virginia", "University of North Carolina-Chapel Hill",
    "University of Southern California", "University of California-San Diego", "New York University",
    "University of Florida", "University of Texas-Austin", "Georgia Institute of Technology",
    "University of California-Davis", "University of California-Irvine", "University of Illinois-Urbana-Champaign",
    "Boston College", "Tufts University", "University of California-Santa Barbara",
    "University of Wisconsin-Madison", "Boston University", "Ohio State University-Columbus",
    "Rutgers University-New Brunswick", "University of Maryland-College Park", "University of Rochester",
    "Lehigh University", "Purdue University", "University of Georgia", "University of Washington",
    "Wake Forest University"]

# %%
# Building a function to find the coordinates of a given location (latitude & longitude)

# %%
def find_coordinates(location_name):
    """
    Finds the latitude and longitude of a given location name.
    
    Args:
        location_name (str): The name of the location.
    
    Returns:
        tuple: A tuple containing latitude and longitude.
               Returns None if the location is not found.
    """
    geolocator = Nominatim(user_agent="geo_locator")
    try:
        location = geolocator.geocode(location_name)
        return location.latitude, location.longitude
    except GeocoderTimedOut:
        time.sleep(1)  # Retry after a short delay
        return find_coordinates(location_name)

# %%
# Initialize an empty list to store the results
data = []

# Iterate through the list of universities and fetch their coordinates
for university in universities:
    lat, lon = find_coordinates(university)
    data.append({"School Name": university, "Latitude": lat, "Longitude": lon})

# Create a DataFrame from the collected data
universities_df = pd.DataFrame(data)

# %%
universities_df.head()
# Out:
#                              School Name   Latitude   Longitude
# 0                   Princeton University  40.338675  -74.658365
# 1  Massachusetts Institute of Technology  42.358253  -71.096627
# 2                     Harvard University  42.365743  -71.122214
# 3                    Stanford University  37.431314 -122.169365
# 4                        Yale University  41.257131  -72.989670

# %%
# Define timelines
timelines = {"Sep.1 - Dec.31": (datetime(2018, 9, 1), datetime(2018, 12, 31)),
    "Jan.1 - April.30": (datetime(2018, 1, 1), datetime(2018, 4, 30)),
    "May.1 - Aug.31": (datetime(2018, 5, 1), datetime(2018, 8, 31))}

# Iterate through each university and fetch weather data
for timeline_name, (start, end) in timelines.items():
    avg_tavg_column = f"{timeline_name} Avg TAVG"
    avg_prcp_column = f"{timeline_name} Avg PRCP"
    
    universities_df[avg_tavg_column] = None
    universities_df[avg_prcp_column] = None

    for index, row in universities_df.iterrows():
        location = Point(row["Latitude"], row["Longitude"])
        weather_data = Daily(location, start, end).fetch()

        # Calculate averages of tavg and prcp
        avg_tavg = weather_data["tavg"].mean()
        avg_prcp = weather_data["prcp"].mean()

        # Add data to the DataFrame
        universities_df.at[index, avg_tavg_column] = avg_tavg
        universities_df.at[index, avg_prcp_column] = avg_prcp

# %%
# Replace NaNs with 0 in the DataFrame
universities_df = universities_df.fillna(0)

# %%
# Display DataFrame
universities_df.head(50)
# Out:
#                                  School Name   Latitude   Longitude  \
# 0                       Princeton University  40.338675  -74.658365
# 1      Massachusetts Institute of Technology  42.358253  -71.096627
# 2                         Harvard University  42.365743  -71.122214
# 3                        Stanford University  37.431314 -122.169365
# 4                            Yale University  41.257131  -72.989670
# 5         California Institute of Technology  34.137014 -118.125288
# 6                            Duke University  36.000156  -78.944230
# 7                   Johns Hopkins University  39.330202  -76.621854
# 8                    Northwestern University  42.055716  -87.675295
# 9                 University of Pennsylvania  39.949340  -75.189649
# 10                        Cornell University  42.452908  -76.480084
# 11                     University of Chicago  41.791397  -87.600844
# 12                          Brown University  41.818640  -71.408801
# 13                       Columbia University  40.807756  -73.961614
# 14                         Dartmouth College  43.704676  -72.294209
# 15      University of California-Los Angeles  34.070878 -118.446850
# 16         University of California-Berkeley  37.875500 -122.239069
# 17                           Rice University  29.716791  -95.404781
# 18                  University of Notre Dame  41.704568  -86.238220
# 19                     Vanderbilt University  36.143801  -86.802819
# 20                Carnegie Mellon University  40.444190  -79.942719
# 21          University of Michigan-Ann Arbor  42.294214  -83.710039
# 22        Washington University in St. Louis  38.647240  -90.308402
# 23                          Emory University  33.800455  -84.317238
# 24                     Georgetown University  38.908939  -77.074580
# 25                    University of Virginia  38.041058  -78.505508
# 26  University of North Carolina-Chapel Hill  35.905035  -79.047753
# 27         University of Southern California  34.021869 -118.285858
# 28        University of California-San Diego  32.879244 -117.231125
# 29                       New York University  40.729205  -73.995015
# 30                     University of Florida  29.632884  -82.349013
# 31                University of Texas-Austin  30.285149  -97.733935
# 32           Georgia Institute of Technology  33.776095  -84.398808
# 33            University of California-Davis  38.533790 -121.790754
# 34           University of California-Irvine  33.642947 -117.840161
# 35   University of Illinois-Urbana-Champaign  40.076154  -88.223313
# 36                            Boston College  42.335448  -71.168266
# 37                          Tufts University  42.406491  -71.118007
# 38    University of California-Santa Barbara  34.414602 -119.845810
# 39           University of Wisconsin-Madison  43.080274  -89.430959
# 40                         Boston University  42.350421  -71.103228
# 41            Ohio State University-Columbus  40.005680  -83.028661
# 42          Rutgers University-New Brunswick  40.492978  -74.445108
# 43       University of Maryland-College Park  38.990412  -76.943859
# 44                   University of Rochester  43.129864  -77.628784
# 45                         Lehigh University  40.606803  -75.378249
# 46                         Purdue University  40.430028  -86.926421
# 47                     University of Georgia  33.940428  -83.373049
# 48                  University of Washington  47.655430 -122.300169
# 49                    Wake Forest University  36.134335  -80.278115
#
#     Sep.1 - Dec.31 Avg TAVG  Sep.1 - Dec.31 Avg PRCP  \
# 0                 11.488525                 3.429907
# 1                 10.411475                 4.347541
# 2                 10.411475                 4.347541
# 3                 14.922951                 0.463115
# 4                 11.069672                 4.619672
# 5                 17.866393                 0.829508
# 6                 14.294262                 5.388525
# 7                 13.431148                 5.536066
# 8                  8.565574                 2.827869
# 9                 12.077049                 5.885246
# 10                 7.142982                 0.000000
# 11                 8.891803                 2.966393
# 12                 9.792623                 6.079508
# 13                11.585246                 4.668033
# 14                 6.215702                 1.338636
# 15                17.866393                 0.829508
# 16                14.165574                 1.054918
# 17                18.394262                 4.538525
# 18                 7.777869                 2.785246
# 19                13.618033                 4.109016
# 20                 9.238525                 4.516393
# 21                 7.309836                 1.097674
# 22                11.076230                 2.671311
# 23                14.943443                 4.795902
# 24                13.661475                 5.452459
# 25                13.066116                 2.419101
# 26                14.294262                 5.388525
# 27                18.195902                 0.819672
# 28                18.854918                 0.916393
# 29                12.766393                 4.894262
# 30                20.807377                 3.158197
# 31                17.827869                 4.846721
# 32                15.304918                 5.119672
# 33                15.060656                 1.144262
# 34                18.572131                 0.558197
# 35                 9.164754                 1.117021
# 36                10.411475                 4.347541
# 37                10.411475                 4.347541
# 38                15.722951                 0.739344
# 39                 6.161475                 3.040984
# 40                10.411475                 4.347541
# 41                 9.768033                 1.949315
# 42                11.180992                 2.919388
# 43                13.661475                 5.452459
# 44                 8.437705                 2.868852
# 45                10.691803                 5.388525
# 46                 8.828689                 1.821875
# 47                15.311475                 5.049180
# 48                10.832787                 3.136066
# 49                13.453279                 6.213934
#
#     Jan.1 - April.30 Avg TAVG  Jan.1 - April.30 Avg PRCP  \
# 0                    4.315000                   1.672727
# 1                    2.750833                   3.891667
# 2                    2.750833                   3.891667
# 3                   12.549167                   1.324167
# 4                    3.278333                   3.325000
# 5                   15.536667                   1.302500
# 6                    8.890000                   3.339167
# 7                    6.550000                   2.802500
# 8                    0.567500                   2.107500
# 9                    5.000833                   3.716667
# 10                  -0.773109                   0.000000
# 11                   1.182500                   2.216667
# 12                   3.294167                   4.793333
# 13                   4.269167                   3.731667
# 14                  -0.853333                   0.804110
# 15                  15.536667                   1.302500
# 16                  11.785833                   2.490833
# 17                  15.605000                   2.364167
# 18                  -0.071667                   3.135833
# 19                   8.219167                   4.762500
# 20                   2.367500                   3.961667
# 21                  -0.256667                   0.707229
# 22                   4.560000                   3.081667
# 23                  10.150000                   4.500833
# 24                   6.731667                   2.380833
# 25                   7.390833                   0.885057
# 26                   8.890000                   3.339167
# 27                  15.499167                   0.772500
# 28                  16.265000                   0.551667
# 29                   4.996667                   3.893333
# 30                  16.090833                   3.347500
# 31                  15.202500                   1.314167
# 32                  10.746667                   4.523333
# 33                  11.548333                   2.890000
# 34                  15.632500                   0.672500
# 35                   1.602500                   1.516667
# 36                   2.750833                   3.891667
# 37                   2.750833                   3.891667
# 38                  13.084167                   1.744167
# 39                  -1.930833                   1.495833
# 40                   2.750833                   3.891667
# 41                   2.543333                   1.080357
# 42                   4.021667                   1.688636
# 43                   5.443333                   2.380833
# 44                   0.507500                   2.496667
# 45                   3.406780                   3.302500
# 46                   1.255833                   1.193976
# 47                  10.930833                   4.040833
# 48                   7.935000                   3.877500
# 49                   8.179167                   3.170000
#
#     May.1 - Aug.31 Avg TAVG  May.1 - Aug.31 Avg PRCP
# 0                 22.952033                 3.187619
# 1                 21.281301                 2.906504
# 2                 21.281301                 2.906504
# 3                 17.672358                 0.002439
# 4                 21.445528                 2.574797
# 5                 22.191870                 0.022764
# 6                 24.885366                 3.849593
# 7                 25.304878                 6.033333
# 8                 22.076423                 4.304878
# 9                 23.417886                 3.247967
# 10                19.458824                 0.000000
# 11                22.910569                 4.003252
# 12                21.295935                 2.411382
# 13                23.401626                 3.701626
# 14                19.751220                 1.432292
# 15                22.191870                 0.022764
# 16                15.925203                 0.000000
# 17                26.661789                 2.602439
# 18                21.255285                 4.517886
# 19                25.386992                 3.362602
# 20                21.869919                 3.599187
# 21                20.737398                 1.555660
# 22                24.945528                 3.616260
# 23                24.526829                 4.223577
# 24                24.930894                 5.960163
# 25                24.181301                 2.323913
# 26                24.885366                 3.849593
# 27                20.764228                 0.004878
# 28                22.186179                 0.014634
# 29                23.246341                 3.687805
# 30                26.405691                 6.053659
# 31                29.212195                 2.284553
# 32                24.852846                 4.795122
# 33                21.586179                 0.037398
# 34                21.271545                 0.013008
# 35                23.054472                 2.732039
# 36                21.281301                 2.906504
# 37                21.281301                 2.906504
# 38                18.515447                 0.000000
# 39                20.946341                 5.986179
# 40                21.281301                 2.906504
# 41                22.639024                 1.823762
# 42                21.967480                 1.958889
# 43                23.292683                 5.960163
# 44                21.370732                 2.025203
# 45                22.680488                 5.266667
# 46                22.390678                 2.650476
# 47                24.536585                 5.353659
# 48                18.447967                 0.221951
# 49                24.510569                 3.988618

# %%
# Create a map centered on North America
map_na = folium.Map(location=[39.8283, -98.5795], tiles='cartodbpositron', zoom_start=4)

# Add university points to the map
for idx, row in universities_df.iterrows():
    folium.Marker(location=[row["Latitude"], row["Longitude"]],popup=f"{row['School Name']}").add_to(map_na)

# Display the map
map_na
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e4799fc88ec6d815edb85a6563f75b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e4799fc88ec6d815edb85a6563f75b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e4799fc88ec6d815edb85a6563f75b6 = L.map(
#                 &quot;map_5e4799fc88ec6d815edb85a6563f75b6&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ecb1e04796d737af2f035c120e2acd2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3ecb1e04796d737af2f035c120e2acd2.addTo(map_5e4799fc88ec6d815edb85a6563f75b6);
#
#
#             var marker_723a0794d2660e923e7d68ac9ef936e5 = L.marker(
#                 [40.33867515, -74.65836549131683],
#                 {}
#             ).addTo(map_5e4799fc88ec6d815edb85a6563f75b6);
#
#
#         var popup_035ceec83699a8f1dc9e6023c8c2e7b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc2030186263f7db64b691b9382ef647 = $(`&lt;div id=&quot;html_bc2030186263f7db64b691b9382ef647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Princeton University&lt;/div&gt;`)[0];
#                 popup_035ceec83699a8f1dc9e6023c8c2e7b0.setContent(html_bc2030186263f7db64b691b9382ef647);
#
#
#
#         marker_723a0794d2660e923e7d68ac9ef936e5.bindPopup(popup_035ceec83699a8f1dc9e6023c8c2e7b0)
#         ;
#
#
#
#
#             var marker_758d34ec28f83fdfefcd73a020978fe0 = L.marker(
#                 [42.3582529, -71.0966272383055],
#                 {}
#             ).addTo(map_5e4799fc88ec6d815edb85a6563f75b6);
#
#
#         var popup_1013d9f30ef1490e84981d6f5ea90311 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b42848fd649019d44975104ab5f386cb = $(`&lt;div id=&quot;html_b42848fd649019d44975104ab5f386cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Massachusetts Institute of Technology&lt;/div&gt;`)[0];
#                 popup_1013d9f30ef1490e84981d6f5ea90311.setContent(html_b42848fd649019d44975104ab5f386cb);
#
#
#
#         marker_758d34ec28f83fdfefcd73a020978fe0.bindPopup(popup_1013d9f30ef1490e84981d6f5ea90311)
#         ;
#
#
#
#
#             var marker_70ba5d99f2e56b7aa635743c2fcbd5ba = L.marker(
#                 [42.365743249999994, -71.12221394207614],
#                 {}
#             ).addTo(map_5e4799fc88ec6d815edb85a6563f75b6);
#
#
#         var popup_18510152339af3696e3065225038b582 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6baadc506f5d2ec520e250c8f4909b33 = $(`&lt;div id=&quot;html_6baadc506f5d2ec520e250c8f4909b33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harvard University&lt;/div&gt;`)[0];
#                 popup_18510152339af3696e3065225038b582.setContent(html_6baadc506f5d2ec520e250c8f4909b33);
#
#
#
#         marker_70ba5d99f2e56b7aa635743c2fcbd5ba.bindPopup(popup_18510152339af3696e3065225038b582)
#         ;
#
#
#
#
#             var marker_8ec53b979857cdc7744ac6a8d5a7afb6 = L.marker(
#                 [37.431313849999995, -122.16936535498309],
#                 {}
#             ).addTo(map_5e4799fc88ec6d815edb85a6563f75b6);
#
#
#         var popup_2523f7f8fe9a8c88bb85a393324b98d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6570e88a4dcf88dcd59c9468217cb2f6 = $(`&lt;div id=&quot;html_6570e88a4dcf88dcd59c9468217cb2f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stanford University&lt;/div&gt;`)[0];
#                 popup_2523f7f8fe9a8c88bb85a393324b98d2.setContent(html_6570e88a4dcf88dcd59c9468217cb2f6);
#
#
#
#         marker_8ec53b979857cdc7744ac6a8d5a7afb6.bindPopup(popup_2523f7f8fe9a8c88bb85a393324b98d2)
#         ;
#
#
#
#
#             var marker_8e5df06ccc309b8a9a2d2cb1edbbd732 = L.marker(
#                 [41.25713055, -72.98966960152231],
#                 {}
#             ).addTo(map_5e4799fc88ec6d815edb85a6563f75b6);
#
#
#         var popup_bd1bc75921a5a6f861a9dc06ab13061e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42f72391303a8ed9d68cff5507957af8 = $(`&lt;div id=&quot;html_42f72391303a8ed9d68cff5507957af8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yale University&lt;/div&gt;`)[0];
#                 popup_bd1bc75921a5a6f861a9dc06ab13061e.setContent(html_42f72391303a8ed9d68cff5507957af8);
#
#
#
#         marker_8e5df06ccc309b8a9a2d2cb1edbbd732.bindPopup(popup_bd1bc75921a5a6f861a9dc06ab130

# %%
def create_heatmap(dataframe, column):
    # Initialize a map centered on North America
    heatmap = folium.Map(location=[39.8283, -98.5795], tiles='cartodbpositron', zoom_start=4)
    
    # Define the viridis color scale
    viridis_gradient = {
        0.0: '#440154',  # Dark purple
        0.2: '#3b528b',  # Blue
        0.4: '#21908d',  # Teal
        0.6: '#5ec962',  # Green
        0.8: '#fde725',  # Yellow
        1.0: '#ffffbf'   # Light yellow
    }
    
    # Extract the data for the heatmap (latitude, longitude, weight)
    heatmap_data = list(zip(dataframe["Latitude"], dataframe["Longitude"], dataframe[column]))
    
    # Add the HeatMap layer
    HeatMap(data=heatmap_data, radius=20, gradient=viridis_gradient).add_to(heatmap)
    
    return heatmap

# Create heatmaps for average temperature (tavg) for each timeline
heatmap_fall_semester_temp_avg = create_heatmap(universities_df, "Sep.1 - Dec.31 Avg TAVG")
heatmap_winter_semester_temp_avg = create_heatmap(universities_df, "Jan.1 - April.30 Avg TAVG")
heatmap_summer_semester_temp_avg = create_heatmap(universities_df, "May.1 - Aug.31 Avg TAVG")

# %%
# Display heatmaps for temperature average
heatmap_fall_semester_temp_avg  # For the timeline Sep.1 - Dec.31 (Fall Semester)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a16a1488bc994dcc87c123b684288a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a16a1488bc994dcc87c123b684288a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a16a1488bc994dcc87c123b684288a6 = L.map(
#                 &quot;map_3a16a1488bc994dcc87c123b684288a6&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer