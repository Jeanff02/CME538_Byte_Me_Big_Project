# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import time
import folium
from folium import Marker
from folium.plugins import HeatMap
import matplotlib.pyplot as plt

# %%
# Read CSV file
uni_data = pd.read_csv('RMP_Data_Clean_Organized.csv')

uni_data.head()
# Out:
#                               University  Safety  Facilities  Social  \
# 0                   Princeton University     4.5         4.4     4.1
# 1  Massachusetts Institute of Technology     4.5         3.7     3.7
# 2                     Harvard University     3.2         3.2     2.9
# 3                    Stanford University     4.5         4.5     4.0
# 4                        Yale University     3.6         4.1     4.0
#
#    Average Sentiment
# 0           0.250584
# 1           0.468943
# 2           0.035685
# 3           0.595871
# 4           0.427826

# %%
# Top 50 Schools

# %%
# List of universities

universities = ["Princeton University", "Massachusetts Institute of Technology", "Harvard University",
    "Stanford University", "Yale University", "California Institute of Technology",
    "Duke University", "Johns Hopkins University", "Northwestern University",
    "University of Pennsylvania", "Cornell University", "University of Chicago",
    "Brown University", "Columbia University", "Dartmouth College",
    "University of California-Los Angeles", "University of California-Berkeley", "Rice University",
    "University of Notre Dame", "Vanderbilt University", "Carnegie Mellon University",
    "University of Michigan-Ann Arbor", "Washington University in St. Louis", "Emory University",
    "Georgetown University", "University of Virginia", "University of North Carolina-Chapel Hill",
    "University of Southern California", "University of California-San Diego", "New York University",
    "University of Florida", "University of Texas-Austin", "Georgia Institute of Technology",
    "University of California-Davis", "University of California-Irvine", "University of Illinois-Urbana-Champaign",
    "Boston College", "Tufts University", "University of California-Santa Barbara",
    "University of Wisconsin-Madison", "Boston University", "Ohio State University-Columbus",
    "Rutgers University-New Brunswick", "University of Maryland-College Park", "University of Rochester",
    "Lehigh University", "Purdue University", "University of Georgia", "University of Washington",
    "Wake Forest University"]

# %%
# Building a function to find the coordinates of a given location (latitude & longitude)

# %%
def find_coordinates(location_name):
    """
    Finds the latitude and longitude of a given location name.
    
    Args:
        location_name (str): The name of the location.
    
    Returns:
        tuple: A tuple containing latitude and longitude.
               Returns None if the location is not found.
    """
    geolocator = Nominatim(user_agent="geo_locator")
    try:
        location = geolocator.geocode(location_name)
        return location.latitude, location.longitude
    except GeocoderTimedOut:
        time.sleep(1)  # Retry after a short delay
        return find_coordinates(location_name)

# %%
# Apply the function to find coordinates and add new columns
uni_data[['Latitude', 'Longitude']] = uni_data['University'].apply(lambda name: pd.Series(find_coordinates(name)))

# %%
uni_data.head()
# Out:
#                               University  Safety  Facilities  Social  \
# 0                   Princeton University     4.5         4.4     4.1
# 1  Massachusetts Institute of Technology     4.5         3.7     3.7
# 2                     Harvard University     3.2         3.2     2.9
# 3                    Stanford University     4.5         4.5     4.0
# 4                        Yale University     3.6         4.1     4.0
#
#    Average Sentiment   Latitude   Longitude
# 0           0.250584  40.338675  -74.658365
# 1           0.468943  42.358253  -71.096627
# 2           0.035685  42.365743  -71.122214
# 3           0.595871  37.431314 -122.169365
# 4           0.427826  41.257131  -72.989670

# %%
# Create a map centered on North America
map_na = folium.Map(location=[39.8283, -98.5795], tiles='cartodbpositron', zoom_start=4)

# Add university points to the map
for idx, row in uni_data.iterrows():
    folium.Marker(location=[row["Latitude"], row["Longitude"]],popup=f"{row['University']}").add_to(map_na)

# Display the map
map_na
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fafe547885d263c1f6775f15644dc7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fafe547885d263c1f6775f15644dc7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fafe547885d263c1f6775f15644dc7d = L.map(
#                 &quot;map_7fafe547885d263c1f6775f15644dc7d&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0678171f402a041b2090d583b60611f8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0678171f402a041b2090d583b60611f8.addTo(map_7fafe547885d263c1f6775f15644dc7d);
#
#
#             var marker_3ebec4c0e735081caa9745a01dc83a3b = L.marker(
#                 [40.33867515, -74.65836549131683],
#                 {}
#             ).addTo(map_7fafe547885d263c1f6775f15644dc7d);
#
#
#         var popup_9b99823cd2a6e0cab63e3bf3e42c64a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f970d30141b1fdbbb46946f0fc04e207 = $(`&lt;div id=&quot;html_f970d30141b1fdbbb46946f0fc04e207&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Princeton University&lt;/div&gt;`)[0];
#                 popup_9b99823cd2a6e0cab63e3bf3e42c64a0.setContent(html_f970d30141b1fdbbb46946f0fc04e207);
#
#
#
#         marker_3ebec4c0e735081caa9745a01dc83a3b.bindPopup(popup_9b99823cd2a6e0cab63e3bf3e42c64a0)
#         ;
#
#
#
#
#             var marker_76023b277088c3398186745f47a815fa = L.marker(
#                 [42.3582529, -71.0966272383055],
#                 {}
#             ).addTo(map_7fafe547885d263c1f6775f15644dc7d);
#
#
#         var popup_15eea034ec03f3a5c4ea96f385bdba33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93ee9952cba369b00e883038f278b495 = $(`&lt;div id=&quot;html_93ee9952cba369b00e883038f278b495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Massachusetts Institute of Technology&lt;/div&gt;`)[0];
#                 popup_15eea034ec03f3a5c4ea96f385bdba33.setContent(html_93ee9952cba369b00e883038f278b495);
#
#
#
#         marker_76023b277088c3398186745f47a815fa.bindPopup(popup_15eea034ec03f3a5c4ea96f385bdba33)
#         ;
#
#
#
#
#             var marker_19bb43bb44e550fc43c3531da3268c50 = L.marker(
#                 [42.365743249999994, -71.12221394207614],
#                 {}
#             ).addTo(map_7fafe547885d263c1f6775f15644dc7d);
#
#
#         var popup_d75354eff366cd296cf8597f7a84edf7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f3a7f9a3f3e95599c0d38b1d60223b6 = $(`&lt;div id=&quot;html_4f3a7f9a3f3e95599c0d38b1d60223b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harvard University&lt;/div&gt;`)[0];
#                 popup_d75354eff366cd296cf8597f7a84edf7.setContent(html_4f3a7f9a3f3e95599c0d38b1d60223b6);
#
#
#
#         marker_19bb43bb44e550fc43c3531da3268c50.bindPopup(popup_d75354eff366cd296cf8597f7a84edf7)
#         ;
#
#
#
#
#             var marker_3de2273f21b4a4948a1160b88f34b847 = L.marker(
#                 [37.431313849999995, -122.16936535498309],
#                 {}
#             ).addTo(map_7fafe547885d263c1f6775f15644dc7d);
#
#
#         var popup_b1332dc4577edf842f341b59a76c795e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3465eba00b8a14fda46f7580b6f63b2f = $(`&lt;div id=&quot;html_3465eba00b8a14fda46f7580b6f63b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stanford University&lt;/div&gt;`)[0];
#                 popup_b1332dc4577edf842f341b59a76c795e.setContent(html_3465eba00b8a14fda46f7580b6f63b2f);
#
#
#
#         marker_3de2273f21b4a4948a1160b88f34b847.bindPopup(popup_b1332dc4577edf842f341b59a76c795e)
#         ;
#
#
#
#
#             var marker_9f397ca089107171f97bb31aef54d2a4 = L.marker(
#                 [41.25713055, -72.98966960152231],
#                 {}
#             ).addTo(map_7fafe547885d263c1f6775f15644dc7d);
#
#
#         var popup_825ef1ed566f5254973ffef3bb7b5b52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04aec2e2d6fb90eee7d1889c8176cdba = $(`&lt;div id=&quot;html_04aec2e2d6fb90eee7d1889c8176cdba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yale University&lt;/div&gt;`)[0];
#                 popup_825ef1ed566f5254973ffef3bb7b5b52.setContent(html_04aec2e2d6fb90eee7d1889c8176cdba);
#
#
#
#         marker_9f397ca089107171f97bb31aef54d2a4.bindPopup(popup_825ef1ed566f5254973ffef3bb7b5

# %%
def create_heatmap(dataframe, column):
    # Initialize a map centered on North America
    heatmap = folium.Map(location=[39.8283, -98.5795], tiles='cartodbpositron', zoom_start=4)
    
    # Define the viridis color scale
    viridis_gradient = {
        0.0: '#440154',  # Dark purple
        0.2: '#3b528b',  # Blue
        0.4: '#21908d',  # Teal
        0.6: '#5ec962',  # Green
        0.8: '#fde725',  # Yellow
        1.0: '#ffffbf'   # Light yellow
    }
    
    # Extract the data for the heatmap (latitude, longitude, weight)
    heatmap_data = list(zip(dataframe["Latitude"], dataframe["Longitude"], dataframe[column]))
    
    # Add the HeatMap layer
    HeatMap(data=heatmap_data, radius=20, gradient=viridis_gradient).add_to(heatmap)
    
    return heatmap

# %%
# Create heatmaps
heatmap_safety = create_heatmap(uni_data, "Safety")
heatmap_facilities = create_heatmap(uni_data, "Facilities")
heatmap_social = create_heatmap(uni_data, "Social")
heatmap_sentiment = create_heatmap(uni_data, "Average Sentiment")

# %%
# Display heatmap for safety score per school
heatmap_safety
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_743c0f6f1a1939d23450ac78826c5f05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_743c0f6f1a1939d23450ac78826c5f05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_743c0f6f1a1939d23450ac78826c5f05 = L.map(
#                 &quot;map_743c0f6f1a1939d23450ac78826c5f05&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_797daafb682b36c479dfbcbaca03a994 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_797daafb682b36c479dfbcbaca03a994.addTo(map_743c0f6f1a1939d23450ac78826c5f05);
#
#
#             var heat_map_95296ee34865068b80e3a45674347f47 = L.heatLayer(
#                 [[40.33867515, -74.65836549131683, 4.5], [42.3582529, -71.0966272383055, 4.5], [42.365743249999994, -71.12221394207614, 3.2], [37.431313849999995, -122.16936535498309, 4.5], [41.25713055, -72.98966960152231, 3.6], [34.13701375, -118.12528833668254, 4.2], [36.00015569999999, -78.94422972195878, 4.4], [39.33020225, -76.62185357858337, 3.2], [42.0557157, -87.67529454739416, 4.3], [39.949340449999994, -75.18964936995958, 3.5], [42.4529076, -76.48008423030923, 4.4], [41.79139685, -87.60084387193544, 2.9], [41.8186395, -71.4088008716793, 4.5], [40.80775585, -73.96161411567529, 3.5], [43.70467565, -72.29420886774966, 4.2], [34.070877749999994, -118.44685031405575, 4.0], [37.875499649999995, -122.23906851395179, 2.7], [29.716791450000002, -95.40478113393792, 4.3], [41.704567749999995, -86.23822026017265, 4.4], [36.14380105, -86.80281889095295, 4.5], [40.444189699999995, -79.94271918393466, 4.3], [42.2942142, -83.71003893509601, 4.4], [38.64724015, -90.30840171586841, 3.9], [33.80045465, -84.31723780466274, 4.7], [38.90893925, -77.07457962060826, 4.2], [38.0410576, -78.50550841214823, 4.0], [35.90503535, -79.04775326525107, 4.0], [34.02186895, -118.285857923125, 3.5], [32.87924375, -117.23112468377349, 4.2], [40.729205300000004, -73.99501481290962, 3.5], [29.6328837, -82.34901302237435, 4.2], [30.2851494, -97.73393515146053, 3.4], [33.776094799999996, -84.3988076699857, 3.9], [38.533790350000004, -121.79075439946112, 4.3], [33.64294685, -