# %%
pip install fuzzywuzzy[speedup] pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: fuzzywuzzy[speedup] in /opt/conda/lib/python3.11/site-packages (0.18.0)
# Requirement already satisfied: python-levenshtein>=0.12 in /opt/conda/lib/python3.11/site-packages (from fuzzywuzzy[speedup]) (0.26.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: Levenshtein==0.26.1 in /opt/conda/lib/python3.11/site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]) (0.26.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /opt/conda/lib/python3.11/site-packages (from Levenshtein==0.26.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]) (3.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import json
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import time
import folium
from folium import Marker
from folium.plugins import HeatMap
from fuzzywuzzy import process

# %%
uni_data = pd.DataFrame(columns=['University Name','In State Tuition','Out of State Tuition','Admission Rate','Number of Students','Graduation Rate 4-years',
                                'Earnings After 10 Years','Retention Rate','Diversity Score','Public or Private'])

university_list = ['Princeton University','Massachusetts Institute of Technology','Harvard University','Stanford University','Yale University',
                   'California Institute of Technology','Duke University','Johns Hopkins University','Northwestern University',
                   'University of Pennsylvania','Cornell University','University of Chicago','Brown University','Columbia University',
                   'Dartmouth College','University of California-Los Angeles','University of California-Berkeley','Rice University','University of Notre Dame','Vanderbilt University', 'Carnegie Mellon University',
                  'University of Michigan','Washington University','Emory University',"Georgetown University","University of Virginia",
                   "University of North Carolina-Chapel Hill", "University of Southern California","University of California-San Diego",
                   "New York University","University of Florida","University of Texas-Austin","Georgia Institute of Technology",
                   "University of California-Davis","University of California-Irvine","University of Illinois-Urbana-Champaign","Boston College",
                   "Tufts University","University of California-Santa Barbara","University of Wisconsin-Madison","Boston University",
                   "Ohio State University","Rutgers University","University of Maryland","University of Rochester",
                   "Lehigh University","Purdue University","University of Georgia","University of Washington","Wake Forest University"]

for university in university_list:
    url = "https://api.data.gov/ed/collegescorecard/v1/schools?api_key=OvEQIo28yxxsUWagGnOrXt9vuxU1WbanzSm1V8Dp&school.name="+university+"&fields=id,school.name,latest.cost.tuition.in_state,latest.cost.tuition.out_of_state,latest.admissions.admission_rate.overall,latest.student.size,latest.completion.rate_suppressed.four_year,latest.earnings.10_yrs_after_entry.median,latest.student.retention_rate.overall.full_time,latest.school.peps_ownership,latest.student.demographics.race_ethnicity.asian,latest.student.demographics.race_ethnicity.black,latest.student.demographics.race_ethnicity.white"
    response = requests.get(url)
    data = response.json()
    
    in_state_tuition = data['results'][0]['latest.cost.tuition.in_state']
    out_of_state_tuition = data['results'][0]['latest.cost.tuition.out_of_state']
    admission_rate = data['results'][0]['latest.admissions.admission_rate.overall']
    student_size = data['results'][0]['latest.student.size']
    completion_rate = data['results'][0]['latest.completion.rate_suppressed.four_year']
    earning_10year = data['results'][0]['latest.earnings.10_yrs_after_entry.median']
    retention_rate = data['results'][0]['latest.student.retention_rate.overall.full_time']
    ownership = data['results'][0]['latest.school.peps_ownership']
    prop_white = data['results'][0]['latest.student.demographics.race_ethnicity.white']
    prop_black = data['results'][0]['latest.student.demographics.race_ethnicity.black']
    prop_asian = data['results'][0]['latest.student.demographics.race_ethnicity.asian']

    if all(p is not None for p in [prop_white, prop_black, prop_asian]):
        prop_other = 1-prop_white-prop_black-prop_asian
        proportions = [prop_white,prop_black,prop_asian,prop_other]
        diversity_score = 1 - sum(p**2 for p in proportions)
    else:
        diversity_score = None
        
    uni_data.loc[len(uni_data)] = {'University Name': university, 'In State Tuition': in_state_tuition, 'Out of State Tuition': out_of_state_tuition, 
                                   'Admission Rate': admission_rate, 'Number of Students': student_size,'Graduation Rate 4-years': completion_rate,
                                  'Earnings After 10 Years': earning_10year,'Retention Rate': retention_rate, 'Diversity Score': diversity_score,
                                   'Public or Private': ownership}
# Out:
# FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
# Inputting missing data for cornell university
uni_data.loc[10, 'Admission Rate'] = 0.079
uni_data.loc[10, 'Number of Students'] = 16071
uni_data.loc[10, 'In State Tuition'] = 63200
uni_data.loc[10, 'Out of State Tuition'] = 63200
uni_data.loc[10, 'Retention Rate'] = 0.96
1-0.385-0.077-0.363
proportions = [0.303,0.0588,0.179,1-0.303-0.0588-0.179]
diversity_score = 1 - sum(p**2 for p in proportions)
uni_data.loc[10, 'Diversity Score'] = diversity_score
# Inputting missing data for California Institute of Technology
uni_data.loc[5, 'Admission Rate'] = 0.027
# Inputting missing data for Boston College
uni_data.loc[36, 'Admission Rate'] = 0.167
# Inputting missing data for Ohio State University
uni_data.loc[41, 'Admission Rate'] = 0.027

# %%
uni_data.head(50)
# Out:
#                              University Name  In State Tuition  \
# 0                       Princeton University             57410
# 1      Massachusetts Institute of Technology             57986
# 2                         Harvard University             57261
# 3                        Stanford University             58416
# 4                            Yale University             62250
# 5         California Institute of Technology             19190
# 6                            Duke University             62688
# 7                   Johns Hopkins University             60480
# 8                    Northwestern University              8672
# 9                 University of Pennsylvania             63452
# 10                        Cornell University             63200
# 11                     University of Chicago             14046
# 12                          Brown University             29720
# 13                       Columbia University             66139
# 14                         Dartmouth College             62658
# 15      University of California-Los Angeles              6805
# 16         University of California-Berkeley             14395
# 17                           Rice University             54960
# 18                  University of Notre Dame             60301
# 19                     Vanderbilt University             60348
# 20                Carnegie Mellon University             61344
# 21                    University of Michigan             16736
# 22                     Washington University              8967
# 23                          Emory University             57948
# 24                     Georgetown University             62052
# 25                    University of Virginia             20342
# 26  University of North Carolina-Chapel Hill              8989
# 27         University of Southern California             38700
# 28        University of California-San Diego             14906
# 29                       New York University              8524
# 30                     University of Florida              5656
# 31                University of Texas-Austin             11698
# 32           Georgia Institute of Technology             11764
# 33            University of California-Davis             14858
# 34           University of California-Irvine             13939
# 35   University of Illinois-Urbana-Champaign             15714
# 36                            Boston College             22144
# 37                          Tufts University             65222
# 38    University of California-Santa Barbara             14617
# 39           University of Wisconsin-Madison             10796
# 40                         Boston University             62360
# 41                     Ohio State University              8998
# 42                        Rutgers University             16112
# 43                    University of Maryland             53430
# 44                   University of Rochester             26736
# 45                         Lehigh University             59930
# 46                         Purdue University              8985
# 47                     University of Georgia              4980
# 48                  University of Washington              8967
# 49                    Wake Forest University             62128
#
#     Out of State Tuition  Admission Rate  Number of Students  \
# 0                  57410          0.0570                5527
# 1                  57986          0.0396                4638
# 2                  57261          0.0324                7973
# 3                  58416          0.0368                7761
# 4                  62250          0.0457                6639
# 5                  19190          0.0270                 540
# 6                  62688          0.0635                6570
# 7                  60480          0.0725                5643
# 8                  19460          0.9793                6243
# 45                   0.8926                   105584          0.9085
# 46                   0.3701                    45872          0.6272
# 47                   0.3522                    48757          0.5973
# 48                   0.6650                    62569          0.7736
# 49                   0.8994                    78158          0.9376
#
#     Diversity Score  Public or Private
# 0          0.701479  Private Nonprofit
# 1          0.699191  Private Nonprofit
# 2          0.703174  Private Nonprofit
# 3          0.694972  Private Nonprofit
# 4          0.702715  Private Nonprofit
# 5          0.483280        Proprietary
# 6          0.700444  Private Nonprofit
# 7          0.688898  Private Nonprofit
# 8          0.600800             Public
# 9          0.709739  Private Nonprofit
# 10         0.661828  Private Nonprofit
# 11         0.665014             Public
# 12         0.431634  Private Nonprofit
# 13         0.679876  Private Nonprofit
# 14         0.644170  Private Nonprofit
# 15         0.335057             Public
# 16         0.654043             Public
# 17         0.708928  Private Nonprofit
# 18         0.518160  Private Nonprofit
# 19         0.694480  Private Nonprofit
# 20         0.673670  Private Nonprofit
# 21         0.632797             Public
# 22         0.468993             Public
# 23         0.706744  Private Nonprofit
# 24         0.632342  Private Nonprofit
# 25         0.637681             Public
# 26         0.620395             Public
# 27         0.548857  Private Nonprofit
# 28         0.639903             Public
# 29         0.557727             Public
# 30         0.559907             Public
# 31         0.684622             Public
# 32         0.700213             Public
# 33         0.646977             Public
# 34         0.618169             Public
# 35         0.686578             Public
# 36         0.597781  Private Nonprofit
# 37         0.659435  Private Nonprofit
# 38         0.634496             Public
# 39         0.534317             Public
# 40         0.671706  Private Nonprofit
# 41         0.129708             Public
# 42         0.710127             Public
# 43         0.516167  Private Nonprofit
# 44         0.558933  Private Nonprofit
# 45         0.567735  Private Nonprofit
# 46         0.455198             Public
# 47         0.585268             Public
# 48         0.468993             Public
# 49         0.503522  Private Nonprofit

# %%
standard_names = ['Princeton University',
 'Massachusetts Institute of Technology',
 'Harvard University',
 'Stanford University',
 'Yale University',
 'California Institute of Technology',
 'Duke University',
 'Johns Hopkins University',
 'Northwestern University',
 'University of Pennsylvania',
 'Cornell University',
 'University of Chicago',
 'Brown University',
 'Columbia University',
 'Dartmouth College',
 'University of California, Los Angeles',
 'University of California, Berkeley',
 'Rice University',
 'University of Notre Dame',
 'Vanderbilt University',
 'Carnegie Mellon University',
 'University of Michigan, Ann Arbor',
 'Washington University in St. Louis',
 'Emory University',
 'Georgetown University',
 'University of Virginia',
 'University of North Carolina, Chapel Hill',
 'University of Southern California',
 'University of California, San Diego',
 'New York University',
 'University of Florida',
 'University of Texas, Austin',
 'Georgia Institute of Technology',
 'University of California, Davis',
 'University of California, Irvine',
 'University of Illinois, Urbana-Champaign',
 'Boston College',
 'Tufts University',
 'University of California, Santa Barbara',
 'University of Wisconsin, Madison',
 'Boston University',
 'Ohio State University, Columbus',
 'Rutgers University, New Brunswick',
 'University of Maryland, College Park',
 'University of Rochester',
 'Lehigh University',
 'Purdue University',
 'University of Georgia',
 'University of Washington',
 'Wake Forest University']

# %%
def standardize_column_values(df, column, standard_names, threshold=80):

    updated_values = []
    
    for value in df[column]:
        match, score = process.extractOne(value, standard_names)
        if score >= threshold:
            updated_values.append(match)  # Use the matched standard name
        else:
            updated_values.append(value)  # Keep the original name if no good match
    
    df[column] = updated_values
    return df

# %%
uni_data = standardize_column_values(uni_data, 'University Name', standard_names, threshold=80)
uni_data.head(50)
# Out:
#                               University Name  In State Tuition  \
# 0                        Princeton University             57410
# 1       Massachusetts Institute of Technology             57986
# 2                          Harvard University             57261
# 3                         Stanford University             58416
# 4                             Yale University             62250
# 5          California Institute of Technology             19190
# 6                             Duke University             62688
# 7                    Johns Hopkins University             60480
# 8                     Northwestern University              8672
# 9                  University of Pennsylvania             63452
# 10                         Cornell University             63200
# 11                      University of Chicago             14046
# 12                           Brown University             29720
# 13                        Columbia University             66139
# 14                          Dartmouth College             62658
# 15      University of California, Los Angeles              6805
# 16         University of California, Berkeley             14395
# 17                            Rice University             54960
# 18                   University of Notre Dame             60301
# 19                      Vanderbilt University             60348
# 20                 Carnegie Mellon University             61344
# 21          University of Michigan, Ann Arbor             16736
# 22                   University of Washington              8967
# 23                           Emory University             57948
# 24                      Georgetown University             62052
# 25                     University of Virginia             20342
# 26  University of North Carolina, Chapel Hill              8989
# 27          University of Southern California             38700
# 28        University of California, San Diego             14906
# 29                        New York University              8524
# 30                      University of Florida              5656
# 31                University of Texas, Austin             11698
# 32            Georgia Institute of Technology             11764
# 33            University of California, Davis             14858
# 34           University of California, Irvine             13939
# 35   University of Illinois, Urbana-Champaign             15714
# 36                             Boston College             22144
# 37                           Tufts University             65222
# 38    University of California, Santa Barbara             14617
# 39           University of Wisconsin, Madison             10796
# 40                          Boston University             62360
# 41            Ohio State University, Columbus              8998
# 42          Rutgers University, New Brunswick             16112
# 43       University of Maryland, College Park             53430
# 44                    University of Rochester             26736
# 45                          Lehigh University             59930
# 46                          Purdue University              8985
# 47                      University of Georgia              4980
# 48                   University of Washington              8967
# 49                     Wake Forest University             62128
#
#     Out of State Tuition  Admission Rate  Number of Students  \
# 0                  57410          0.0570                5527
# 1                  57986          0.0396                4638
# 2                  57261          0.0324                7973
# 3                  58416          0.0368                7761
# 4                  62250          0.0457                6639
# 5                  19190          0.0270                 540
# 6                  62688          0.0635                6570
# 7                  60480          0.0725                5643
# 8                  19460          0.9793                6243
# 9                  63452          0.0650               10572
# 10                 63200          0.0790               16071
# 11                 28654          0.7869               21567
# 12                 29720          0.5664                1354
# 13                 66139          0.0395                8902
# 14                 62658          0.0638                4412
# 15                 18685          0.8694               22690
# 16                 44467          0.1133               32475
# 17                 54960          0.0868                4480
# 18                 60301          0.1291                8917
# 19                 60348          0.0667                7144
# 20                 61344          0.1130                7005
# 21                 55334          0.1769               32448
# 22                 26873          0.9269               13686
# 23                 57948          0.1135                7017
# 24                 62052          0.1223                7343
# 25                 55914          0.1866               17103
# 26                 37550          0.1711               19921
# 27                 38700          0.7484                2001
# 28                 44978          0.2371               33092
# 29                 18434          0.5827                5990
# 30                 18786          0.2504               32691
# 31                 41070          0.3135               40980
# 32                 32876          0.1713               17379
# 33                 44930          0.3734               31512
# 34                 44011          0.2115               28651
# 35                 33686          0.4482               34031
# 36                 22144          0.1670                 259
# 37                 65222          0.0969                6747
# 21         0.632797             Public
# 22         0.468993             Public
# 23         0.706744  Private Nonprofit
# 24         0.632342  Private Nonprofit
# 25         0.637681             Public
# 26         0.620395             Public
# 27         0.548857  Private Nonprofit
# 28         0.639903             Public
# 29         0.557727             Public
# 30         0.559907             Public
# 31         0.684622             Public
# 32         0.700213             Public
# 33         0.646977             Public
# 34         0.618169             Public
# 35         0.686578             Public
# 36         0.597781  Private Nonprofit
# 37         0.659435  Private Nonprofit
# 38         0.634496             Public
# 39         0.534317             Public
# 40         0.671706  Private Nonprofit
# 41         0.129708             Public
# 42         0.710127             Public
# 43         0.516167  Private Nonprofit
# 44         0.558933  Private Nonprofit
# 45         0.567735  Private Nonprofit
# 46         0.455198             Public
# 47         0.585268             Public
# 48         0.468993             Public
# 49         0.503522  Private Nonprofit

# %%
# Building a function to find the coordinates of a given location (latitude & longitude)

# %%
def find_coordinates(location_name):
    """
    Finds the latitude and longitude of a given location name.
    
    Args:
        location_name (str): The name of the location.
    
    Returns:
        tuple: A tuple containing latitude and longitude.
               Returns None if the location is not found.
    """
    geolocator = Nominatim(user_agent="geo_locator")
    try:
        location = geolocator.geocode(location_name)
        return location.latitude, location.longitude
    except GeocoderTimedOut:
        time.sleep(1)  # Retry after a short delay
        return find_coordinates(location_name)

# %%
# Apply the function to find coordinates and add new columns
uni_data[['Latitude', 'Longitude']] = uni_data['University Name'].apply(lambda name: pd.Series(find_coordinates(name)))

# %%
uni_data.head(50)
# Out:
#                               University Name  In State Tuition  \
# 0                        Princeton University             57410
# 1       Massachusetts Institute of Technology             57986
# 2                          Harvard University             57261
# 3                         Stanford University             58416
# 4                             Yale University             62250
# 5          California Institute of Technology             19190
# 6                             Duke University             62688
# 7                    Johns Hopkins University             60480
# 8                     Northwestern University              8672
# 9                  University of Pennsylvania             63452
# 10                         Cornell University             63200
# 11                      University of Chicago             14046
# 12                           Brown University             29720
# 13                        Columbia University             66139
# 14                          Dartmouth College             62658
# 15      University of California, Los Angeles              6805
# 16         University of California, Berkeley             14395
# 17                            Rice University             54960
# 18                   University of Notre Dame             60301
# 19                      Vanderbilt University             60348
# 20                 Carnegie Mellon University             61344
# 21          University of Michigan, Ann Arbor             16736
# 22                   University of Washington              8967
# 23                           Emory University             57948
# 24                      Georgetown University             62052
# 25                     University of Virginia             20342
# 26  University of North Carolina, Chapel Hill              8989
# 27          University of Southern California             38700
# 28        University of California, San Diego             14906
# 29                        New York University              8524
# 30                      University of Florida              5656
# 31                University of Texas, Austin             11698
# 32            Georgia Institute of Technology             11764
# 33            University of California, Davis             14858
# 34           University of California, Irvine             13939
# 35   University of Illinois, Urbana-Champaign             15714
# 36                             Boston College             22144
# 37                           Tufts University             65222
# 38    University of California, Santa Barbara             14617
# 39           University of Wisconsin, Madison             10796
# 40                          Boston University             62360
# 41            Ohio State University, Columbus              8998
# 42          Rutgers University, New Brunswick             16112
# 43       University of Maryland, College Park             53430
# 44                    University of Rochester             26736
# 45                          Lehigh University             59930
# 46                          Purdue University              8985
# 47                      University of Georgia              4980
# 48                   University of Washington              8967
folium.Map(location=[39.8283, -98.5795], tiles='cartodbpositron', zoom_start=4)

# Add university points to the map
for idx, row in uni_data.iterrows():
    folium.Marker(location=[row["Latitude"], row["Longitude"]],popup=f"{row['University Name']}").add_to(map_na)

# Display the map
map_na
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b29b500748c709edc5f9ec5594a0a9dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b29b500748c709edc5f9ec5594a0a9dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b29b500748c709edc5f9ec5594a0a9dc = L.map(
#                 &quot;map_b29b500748c709edc5f9ec5594a0a9dc&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a81c8c643cf5e3ceb13ca094bb14305 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a81c8c643cf5e3ceb13ca094bb14305.addTo(map_b29b500748c709edc5f9ec5594a0a9dc);
#
#
#             var marker_5636594aafe8aa443b8b19bb4eece741 = L.marker(
#                 [40.33867515, -74.65836549131683],
#                 {}
#             ).addTo(map_b29b500748c709edc5f9ec5594a0a9dc);
#
#
#         var popup_0ccac2d68eff5dc1d4e41c627128ab62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_978affb38a114e57aa919a827d7bc359 = $(`&lt;div id=&quot;html_978affb38a114e57aa919a827d7bc359&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Princeton University&lt;/div&gt;`)[0];
#                 popup_0ccac2d68eff5dc1d4e41c627128ab62.setContent(html_978affb38a114e57aa919a827d7bc359);
#
#
#
#         marker_5636594aafe8aa443b8b19bb4eece741.bindPopup(popup_0ccac2d68eff5dc1d4e41c627128ab62)
#         ;
#
#
#
#
#             var marker_01f7dcde602b9e336fde5e8e89cbe2a1 = L.marker(
#                 [42.3582529, -71.0966272383055],
#                 {}
#             ).addTo(map_b29b500748c709edc5f9ec5594a0a9dc);
#
#
#         var popup_60a530a8d8784ecb50d8a52e9b1debff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc521259f65f46e07ea38b3db6cb6def = $(`&lt;div id=&quot;html_bc521259f65f46e07ea38b3db6cb6def&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Massachusetts Institute of Technology&lt;/div&gt;`)[0];
#                 popup_60a530a8d8784ecb50d8a52e9b1debff.setContent(html_bc521259f65f46e07ea38b3db6cb6def);
#
#
#
#         marker_01f7dcde602b9e336fde5e8e89cbe2a1.bindPopup(popup_60a530a8d8784ecb50d8a52e9b1debff)
#         ;
#
#
#
#
#             var marker_d0c41daba874000258e72de4ea3ce7e2 = L.marker(
#                 [42.365743249999994, -71.12221394207614],
#                 {}
#             ).addTo(map_b29b500748c709edc5f9ec5594a0a9dc);
#
#
#         var popup_bbadaeaa270181bb7c169d773196616a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31a61d406701328e01c546e4053a9628 = $(`&lt;div id=&quot;html_31a61d406701328e01c546e4053a9628&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harvard University&lt;/div&gt;`)[0];
#                 popup_bbadaeaa270181bb7c169d773196616a.setContent(html_31a61d406701328e01c546e4053a9628);
#
#
#
#         marker_d0c41daba874000258e72de4ea3ce7e2.bindPopup(popup_bbadaeaa270181bb7c169d773196616a)
#         ;
#
#
#
#
#             var marker_94790e748588d8f979454c2b86acdf95 = L.marker(
#                 [37.431313849999995, -122.16936535498309],
#                 {}
#             ).addTo(map_b29b500748c709edc5f9ec5594a0a9dc);
#
#
#         var popup_37a0c64c075cdc561ba45f8262fd2c71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_552f0efd3386a27bafc55f60af971620 = $(`&lt;div id=&quot;html_552f0efd3386a27bafc55f60af971620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stanford University&lt;/div&gt;`)[0];
#                 popup_37a0c64c075cdc561ba45f8262fd2c71.setContent(html_552f0efd3386a27bafc55f60af971620);
#
#
#
#         marker_94790e748588d8f979454c2b86acdf95.bindPopup(popup_37a0c64c075cdc561ba45f8262fd2c71)
#         ;
#
#
#
#
#             var marker_62b66a4d0834305cdb93a077ae0fcbcb = L.marker(
#                 [41.25713055, -72.98966960152231],
#                 {}
#             ).addTo(map_b29b500748c709edc5f9ec5594a0a9dc);
#
#
#         var popup_65e86f84775ceb72d9db3871fa17e421 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51529f5acb33e76771486d2dff2b227e = $(`&lt;div id=&quot;html_51529f5acb33e76771486d2dff2b227e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yale University&lt;/div&gt;`)[0];
#                 popup_65e86f84775ceb72d9db3871fa17e421.setContent(html_51529f5acb33e76771486d2dff2b227e);
#
#
#
#         marker_62b66a4d0834305cdb93a077ae0fcbcb.bindPopup(popup_65e86f84775ceb72d9db3871fa17e

# %%
# Plotting the double bar graph
x = range(len(uni_data))
plt.figure(figsize=(15, 8))

# In-State Tuition Bars
plt.bar(x, uni_data["In State Tuition"], width=0.4, label='In State Tuition', align='center')

# Out-of-State Tuition Bars (Offset)
plt.bar([i + 0.4 for i in x], uni_data["Out of State Tuition"], width=0.4, label='Out of State Tuition', align='center')

# Formatting
plt.xticks([i + 0.2 for i in x], uni_data["University Name"], rotation=90)
plt.ylabel("Tuition Cost (USD)")
plt.title("In-State vs Out-of-State Tuition for Universities")
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Define a function to create a heatmap
def create_heatmap(dataframe, column):
    # Initialize a map centered on North America
    heatmap = folium.Map(location=[39.8283, -98.5795], tiles='cartodbpositron', zoom_start=4)
    
    # Define the viridis color scale
    viridis_gradient = {
        0.0: '#440154',  # Dark purple
        0.2: '#3b528b',  # Blue
        0.4: '#21908d',  # Teal
        0.6: '#5ec962',  # Green
        0.8: '#fde725',  # Yellow
        1.0: '#ffffbf'   # Light yellow
    }
    
    # Extract the data for the heatmap (latitude, longitude, weight)
    heatmap_data = list(zip(dataframe["Latitude"], dataframe["Longitude"], dataframe[column]))
    
    # Add the HeatMap layer
    HeatMap(data=heatmap_data, radius=20, gradient=viridis_gradient).add_to(heatmap)
    
    return heatmap

# %%
# Create heatmaps for in-state and out-of-state tuition
heatmap_in_state = create_heatmap(uni_data, "In State Tuition")
heatmap_out_of_state = create_heatmap(uni_data, "Out of State Tuition")

# %%
# Display heatmaps for in-state tuition 
heatmap_in_state
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cef0eab36a7262351e8e1d18e4772903 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cef0eab36a7262351e8e1d18e4772903&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cef0eab36a7262351e8e1d18e4772903 = L.map(
#                 &quot;map_cef0eab36a7262351e8e1d18e4772903&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21d53f5b3730f9fd313c3203c4f58b37 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_21d53f5b3730f9fd313c3203c4f58b37.addTo(map_cef0eab36a7262351e8e1d18e4772903);
#
#
#             var heat_map_0d7ea114df50654409109be8feff6f60 = L.heatLayer(
#                 [[40.33867515, -74.65836549131683, 57410], [42.3582529, -71.0966272383055, 57986], [42.365743249999994, -71.12221394207614, 57261], [37.431313849999995, -122.16936535498309, 58416], [41.25713055, -72.98966960152231, 62250], [34.13701375, -118.12528833668254, 19190], [36.00015569999999, -78.94422972195878, 62688], [39.33020225, -76.62185357858337, 60480], [42.0557157, -87.67529454739416, 8672], [39.949340449999994, -75.18964936995958, 63452], [42.4529076, -76.48008423030923, 63200], [41.79139685, -87.60084387193544, 14046], [41.8186395, -71.4088008716793, 29720
060826, 62052], [38.0410576, -78.50550841214823, 55914], [35.90503535, -79.04775326525107, 37550], [34.02186895, -118.285857923125, 38700], [32.87924375, -117.23112468377349, 44978], [40.729205300000004, -73.99501481290962, 18434], [29.6328837, -82.34901302237435, 18786], [30.2851494, -97.73393515146053, 41070], [33.776094799999996, -84.3988076699857, 32876], [38.533790350000004, -121.79075439946112, 44930], [33.64294685, -117.84016055716225, 44011], [40.076154450000004, -88.22331340640494, 33686], [42.3354481, -71.16826648999114, 22144], [42.40649125, -71.11800725402092, 65222], [34.414602450000004, -119.84581004701371, 44689], [43.080274450000005, -89.43095871991434, 39427], [42.350421499999996, -71.10322831831216, 62360], [40.00568015, -83.02866123579578, 33235], [40.492977800000006, -74.44510808059266, 33812], [38.9784587, -76.9282678, 53430], [43.129864, -77.62878399245412, 26736], [40.6068028, -75.3782488, 59930], [40.430028, -86.92642114650494, 21573], [33.9404278, -83.37304904988295, 15702], [47.6554303, -122.30016924820552, 26873], [36.134335, -80.2781152, 62128]],
#                 {&quot;blur&quot;: 15, &quot;gradient&quot;: {&quot;0.0&quot;: &quot;#440154&quot;, &quot;0.2&quot;: &quot;#3b528b&quot;, &quot;0.4&quot;: &quot;#21908d&quot;, &quot;0.6&quot;: &quot;#5ec962&quot;, &quot;0.8&quot;: &quot;#fde725&quot;, &quot;1.0&quot;: &quot;#ffffbf&quot;}, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 20}
#             );
#
#
#             heat_map_0d8a43d04cfd508dcf8753780f033131.addTo(map_27a72e124afe148347041bc14a9187b4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create the bar graph for Admission Rate
plt.figure(figsize=(12, 6))
plt.bar(uni_data["University Name"], uni_data["Admission Rate"], align='center')

# Formatting
plt.xticks(rotation=90)
plt.ylabel("Admission Rate")
plt.title("Admission Rate of Universities")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the bar graph for Number of Students
plt.figure(figsize=(12, 6))
plt.bar(uni_data["University Name"], uni_data["Number of Students"], align='center')

# Formatting
plt.xticks(rotation=90)
plt.ylabel("Number of Students")
plt.title("Number of Students of Universities")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the bar graph for Graduation Rate 4-years
plt.figure(figsize=(12, 6))
plt.bar(uni_data["University Name"], uni_data["Graduation Rate 4-years"], align='center')

# Formatting
plt.xticks(rotation=90)
plt.ylabel("Graduation Rate 4-years")
plt.title("Graduation Rate 4-years of Universities")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the bar graph for Retention Rate
plt.figure(figsize=(12, 6))
plt.bar(uni_data["University Name"], uni_data["Retention Rate"], align='center')

# Formatting
plt.xticks(rotation=90)
plt.ylabel("Retention Rate")
plt.title("Retention Rate of Universities")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the bar graph for Earnings After 10 Years
plt.figure(figsize=(12, 6))
plt.bar(uni_data["University Name"], uni_data["Earnings After 10 Years"], align='center')

# Formatting
plt.xticks(rotation=90)
plt.ylabel("Earnings After 10 Years")
plt.title("Earnings After 10 Years of Universities")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the bar graph for Diversity Score
plt.figure(figsize=(12, 6))
plt.bar(uni_data["University Name"], uni_data["Diversity Score"], align='center')

# Formatting
plt.xticks(rotation=90)
plt.ylabel("Diversity Score")
plt.title("Diversity Score of Universities")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Further Analysis

# %%
# Separate data into Private and Public universities
private_uni_data = uni_data[uni_data["Public or Private"] == "Private Nonprofit"]
public_uni_data = uni_data[uni_data["Public or Private"] == "Public"]

# %%
# Create a dual-axis plot for Private universities with Earnings After 10 Years
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot In-State and Out-of-State Tuition on the first y-axis
x = range(len(private_uni_data))
ax1.bar(x, private_uni_data["In State Tuition"], width=0.4, label='In State Tuition', align='center', alpha=0.7)
ax1.bar([i + 0.4 for i in x], private_uni_data["Out of State Tuition"], width=0.4, label='Out of State Tuition', align='center', alpha=0.7)
ax1.set_ylabel("Tuition Cost (USD)")
ax1.set_xticks([i + 0.2 for i in x])
ax1.set_xticklabels(private_uni_data["University Name"], rotation=90)
ax1.set_title("Tuition Costs and Earnings After 10 Years of Private Universities")
ax1.legend(loc="upper left")

# Plot Earnings After 10 Years on the second y-axis
ax2 = ax1.twinx()
ax2.plot([i + 0.2 for i in x], private_uni_data["Earnings After 10 Years"], color='red', marker='o', label='Earnings After 10 Years', linewidth=2)
ax2.set_ylabel("Earnings After 10 Years (USD)")
ax2.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
# Create a dual-axis plot for Public universities with Earnings After 10 Years
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot In-State and Out-of-State Tuition on the first y-axis
x = range(len(public_uni_data))
ax1.bar(x, public_uni_data["In State Tuition"], width=0.4, label='In State Tuition', align='center', alpha=0.7)
ax1.bar([i + 0.4 for i in x], public_uni_data["Out of State Tuition"], width=0.4, label='Out of State Tuition', align='center', alpha=0.7)
ax1.set_ylabel("Tuition Cost (USD)")
ax1.set_xticks([i + 0.2 for i in x])
ax1.set_xticklabels(public_uni_data["University Name"], rotation=90)
ax1.set_title("Tuition Costs and Earnings After 10 Years of Public Universities")
ax1.legend(loc="upper left")

# Plot Earnings After 10 Years on the second y-axis
ax2 = ax1.twinx()
ax2.plot([i + 0.2 for i in x], public_uni_data["Earnings After 10 Years"], color='red', marker='o', label='Earnings After 10 Years', linewidth=2)
ax2.set_ylabel("Earnings After 10 Years (USD)")
ax2.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
# Separate data into Private and Public universities
private_uni_data = uni_data[uni_data["Public or Private"] == "Private Nonprofit"]
public_uni_data = uni_data[uni_data["Public or Private"] == "Public"]

# %%
# Create a dual-axis plot for Private universities
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot In-State and Out-of-State Tuition on the first y-axis
x = range(len(private_uni_data))
ax1.bar(x, private_uni_data["In State Tuition"], width=0.4, label='In State Tuition', align='center', alpha=0.7)
ax1.bar([i + 0.4 for i in x], private_uni_data["Out of State Tuition"], width=0.4, label='Out of State Tuition', align='center', alpha=0.7)
ax1.set_ylabel("Tuition Cost (USD)")
ax1.set_xticks([i + 0.2 for i in x])
ax1.set_xticklabels(private_uni_data["University Name"], rotation=90)
ax1.set_title("Tuition Costs and Diversity Scores of Private Universities")
ax1.legend(loc="upper left")

# Plot Diversity Score on the second y-axis
ax2 = ax1.twinx()
ax2.plot([i + 0.2 for i in x], private_uni_data["Diversity Score"], color='red', marker='o', label='Diversity Score', linewidth=2)
ax2.set_ylabel("Diversity Score")
ax2.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
# Create a dual-axis plot for Public universities
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot In-State and Out-of-State Tuition on the first y-axis
x = range(len(public_uni_data))
ax1.bar(x, public_uni_data["In State Tuition"], width=0.4, label='In State Tuition', align='center', alpha=0.7)
ax1.bar([i + 0.4 for i in x], public_uni_data["Out of State Tuition"], width=0.4, label='Out of State Tuition', align='center', alpha=0.7)
ax1.set_ylabel("Tuition Cost (USD)")
ax1.set_xticks([i + 0.2 for i in x])
ax1.set_xticklabels(public_uni_data["University Name"], rotation=90)
ax1.set_title("Tuition Costs and Diversity Scores of Public Universities")
ax1.legend(loc="upper left")

# Plot Diversity Score on the second y-axis
ax2 = ax1.twinx()
ax2.plot([i + 0.2 for i in x], public_uni_data["Diversity Score"], color='red', marker='o', label='Diversity Score', linewidth=2)
ax2.set_ylabel("Diversity Score")
ax2.legend(loc="upper right")

plt.tight_layout()
plt.show()
